# %% [markdown]
# # Test Notebook for various data files
#
# This notebook contains tests for:
#     - pyspch.timit.read_seg_file()
#     - pyspch.core.read_txt()  ... or read_data_file()
#
# *read_seg_file()* is a segmentation reading routine included with a lot of other TIMIT related definitions
#
# *read_txt()* is suitable for importing corpus style files
#
# TIMIT alphabets:   TIMIT48, TIMIT41
# TIMIT mappings:    timit61_48, timit48_41, timit61_41
#
# 01/04/2022: verified with v0.6.3

# %%
# optional install of the pyspch package
#!pip install git+https://github.com/compi1234/pyspch.git

# %%
# %matplotlib inline
import os,sys,io 
import scipy.signal

from urllib.request import urlopen
from IPython.display import display, Audio, HTML, clear_output
from ipywidgets import interact

import math,time
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec 

import librosa as librosa
    
import pyspch.sp as Sps
import pyspch.display as Spd
import pyspch.core as Spch

# %%
### Predefined symbol sets and mappings (translations).
Spch.timit.TIMIT48, Spch.timit.timit61_41_diff
# Out:
# (['aa',
#   'ae',
#   'ah',
#   'ao',
#   'aw',
#   'ax',
#   'er',
#   'ay',
#   'b',
#   'ch',
#   'd',
#   'dh',
#   'dx',
#   'eh',
#   'el',
#   'm',
#   'en',
#   'ng',
#   'ey',
#   'f',
#   'g',
#   'hh',
#   'ih',
#   'ix',
#   'iy',
#   'jh',
#   'k',
#   'l',
#   'n',
#   'ow',
#   'oy',
#   'p',
#   'r',
#   's',
#   'sh',
#   't',
#   'th',
#   'uh',
#   'uw',
#   'v',
#   'w',
#   'y',
#   'z',
#   'zh',
#   'sil',
#   'epi',
#   'vcl',
#   'cl'],
#  {'axr': 'er',
#   'em': 'm',
#   'eng': 'ng',
#   'nx': 'n',
#   'hv': 'hh',
#   'ux': 'uw',
#   'kcl': 'cl',
#   'pcl': 'cl',
#   'tcl': 'cl',
#   'h#': 'sil',
#   'pau': 'sil',
#   'q': 'sil',
#   'bcl': 'cl',
#   'dcl': 'cl',
#   'gcl': 'cl',
#   'epi': 'sil',
#   'dx': 't',
#   'ax-h': 'ah',
#   'ix': 'ih',
#   'ax': 'ah',
#   'el': 'l',
#   'en': 'n'})

# %% [markdown]
# ## File Objects
#
# pyspch provides generic (read) access to files (locally, mounted, via URL) via
# - open_fobj(): opens any file like objects
# - read_fobj(): reads data from any file like object in a FILE IO object in raw format
# - read_data_file(): reads text data from any file like object (default=list of lines)
# - read_tsv_file(): reads a TAB separated data file
# - load(): loads audio from any file like object

# %% [markdown]
# ### Example 1: read local file into list of lines using native Python

# %%
fname = 'mini_corpus.lst'
dir = '../pyspch/data/'
f = open(dir+fname)
f.read().splitlines()
# Out:
# ['friendly      0.0   -1.  friendly computers',
#  'beed          0.0   -1.  beed bad booed',
#  'f1            0.1  1.30  misinterpret ',
#  'f1            1.3  2.7  expansionist ',
#  'f1            2.80 3.7  circumspect']

# %% [markdown]
# ### Example 2: read_data_file() to read local or remote files
#
# - Reads local or remote files into list of lines
# - optionally splits each line on whitespace in a max of maxcols+1

# %%
fname = 'mini_corpus.lst'
dir = '../pyspch/data/'
dir ='HTTPS://homes.esat.kuleuven.be/~spchlab/data/misc/'
#dir = 'V:public_html/data/misc/'
# read_fobj() would just read the raw data, unencoded
# data = Spch.read_fobj(dir+fname)
#
data_split = Spch.read_data_file(dir+fname,maxcols=3)
data = Spch.read_data_file(dir+fname)
data, data_split
# Out:
# (['friendly      0.0   -1.  friendly computers',
#   'beed          0.0   -1.  beed bad booed',
#   'f1            0.1  1.30  misinterpret',
#   'f1            1.3  2.7  expansionist',
#   'f1            2.80 3.7  circumspect'],
#  [['friendly', '0.0', '-1.', 'friendly computers'],
#   ['beed', '0.0', '-1.', 'beed bad booed'],
#   ['f1', '0.1', '1.30', 'misinterpret'],
#   ['f1', '1.3', '2.7', 'expansionist'],
#   ['f1', '2.80', '3.7', 'circumspect']])

# %%
fname = 'timit_train.corpus'
root ='HTTPS://homes.esat.kuleuven.be/~spchlab/data/timit/'

# read_fobj() would just read the raw data, unencoded
# data = Spch.read_fobj(dir+fname)
#
#data_split = Spch.read_data_file(root+fname,maxcols=3)
data = Spch.read_data_file(root+fname)
data  #, data_split
# Out:
# ['train/dr1/fcjf0/sa1',
#  'train/dr1/fcjf0/sa2',
#  'train/dr1/fcjf0/si1027',
#  'train/dr1/fcjf0/si1657',
#  'train/dr1/fcjf0/si648',
#  'train/dr1/fcjf0/sx127',
#  'train/dr1/fcjf0/sx217',
#  'train/dr1/fcjf0/sx307',
#  'train/dr1/fcjf0/sx37',
#  'train/dr1/fcjf0/sx397',
#  'train/dr1/fdaw0/sa1',
#  'train/dr1/fdaw0/sa2',
#  'train/dr1/fdaw0/si1271',
#  'train/dr1/fdaw0/si1406',
#  'train/dr1/fdaw0/si2036',
#  'train/dr1/fdaw0/sx146',
#  'train/dr1/fdaw0/sx236',
#  'train/dr1/fdaw0/sx326',
#  'train/dr1/fdaw0/sx416',
#  'train/dr1/fdaw0/sx56',
#  'train/dr1/fdml0/sa1',
#  'train/dr1/fdml0/sa2',
#  'train/dr1/fdml0/si1149',
#  'train/dr1/fdml0/si1779',
#  'train/dr1/fdml0/si2075',
#  'train/dr1/fdml0/sx159',
#  'train/dr1/fdml0/sx249',
#  'train/dr1/fdml0/sx339',
#  'train/dr1/fdml0/sx429',
#  'train/dr1/fdml0/sx69',
#  'train/dr1/fecd0/sa1',
#  'train/dr1/fecd0/sa2',
#  'train/dr1/fecd0/si1418',
#  'train/dr1/fecd0/si2048',
#  'train/dr1/fecd0/si788',
#  'train/dr1/fecd0/sx158',
#  'train/dr1/fecd0/sx248',
#  'train/dr1/fecd0/sx338',
#  'train/dr1/fecd0/sx428',
#  'train/dr1/fecd0/sx68',
#  'train/dr1/fetb0/sa1',
#  'train/dr1/fetb0/sa2',
#  'train/dr1/fetb0/si1148',
#  'train/dr1/fetb0/si1778',
#  'train/dr1/fetb0/si518',
#  'train/dr1/fetb0/sx158',
#  'train/dr1/fetb0/sx248',
#  'train/dr1/fetb0/sx338',
#  'train/dr1/fetb0/sx428',
#  'train/dr1/fetb0/sx68',
#  'train/dr1/fjsp0/sa1',
#  'train/dr1/fjsp0/sa2',
#  'train/dr1/fjsp0/si1434',
#  'train/dr1/fjsp0/si1763',
#  'train/dr1/fjsp0/si804',
#  'train/dr1/fjsp0/sx174',
#  'train/dr1/fjsp0/sx264',
#  'train/dr1/fjsp0/sx354',
#  'train/dr1/fjsp0/sx444',
#  'train/dr1/fjsp0/sx84',
#  'train/dr1/fkfb0/sa1',
#  'train/dr1/fkfb0/sa2',
#  'train/dr1/fkfb0/si1608',
#  'train/dr1/fkfb0/si2238',
#  'train/dr1/fkfb0/si978',
#  'train/dr1/fkfb0/sx168',
#  'train/dr1/fkfb0/sx258',
#  'train/dr1/fkfb0/sx348',
#  'train/dr1/fkfb0/sx438',
#  'train/dr1/fkfb0/sx78',
#  'train/dr1/fmem0/sa1',
#  'train/dr1/fmem0/sa2',
#  'train/dr1/fmem0/si1377',
#  'train/dr1/fmem0/si2007',
#  'train/dr1/fmem0/si747',
#  'train/dr1/fmem0/sx117',
#  'train/dr1/fmem0/sx207',
#  'train/dr1/fmem0/sx297',
#  'train/dr1/fmem0/sx333',
#  'train/dr1/fmem0/sx387',
#  'train/dr1/fsah0/sa1',
#  'train/dr1/fsah0/sa2',
#  'train/dr1/fsah0/si1244',
#  'train/dr1/fsah0/si1874',
#  'train/dr1/fsah0/si614',
#  'train/dr1/fsah0/sx164',
#  'train/dr1/fsah0/sx327',
#  'train/dr1/fsah0/sx344',
#  'train/dr1/fsah0/sx434',
#  'train/dr1/fsah0/sx74',
#  'train/dr1/fsjk1/sa1',
#  'train/dr1/fsjk1/sa2',
#  'train/dr1/fsjk1/si1025',
#  'train/dr1/fsjk1/si2285',
#  'train/dr1/fsjk1/si696',
#  'train/dr1/fsjk1/sx125',
#  'train/dr1/fsjk1/sx215',
#  'train/dr1/fsjk1/sx305',
#  'train/dr1/fsjk1/sx35',
#  'train/dr1/fsjk1/sx395',
#  'train/dr1/fsma0/sa1',
#  'train/dr1/fsma0/sa2',
#  'train/dr1/fsma0/si1621',
#  'train/dr1/fsma0/si2251',
#  'train/dr1/fsma0/si991',
#  'train/dr1/fsma0/sx181',
#  'train/dr1/fsma0/sx271',
#  'train/dr1/fsma0/sx361',
#  'train/dr1/fsma0/sx451',
#  'train/dr1/fsma0/sx91',
#  'train/dr1/ftbr0/sa1',
#  'train/dr1/ftbr0/sa2',
#  'train/dr1/ftbr0/si1402',
#  'train/dr1/ftbr0/si2181',
#  'train/dr1/ftbr0/si921',
#  'train/dr1/ftbr0/sx111',
#  'train/dr1/ftbr0/sx201',
#  'train/dr1/ftbr0/sx21',
#  'train/dr1/ftbr0/sx291',
#  'train/dr1/ftbr0/sx381',
#  'train/dr1/fvfb0/sa1',
#  'train/dr1/fvfb0/sa2',
#  'train/dr1/fvfb0/si1032',
#  'train/dr1/fvfb0/si1510',
#  'train/dr1/fvfb0/si2292',
#  'train/dr1/fvfb0/sx132',
#  'train/dr1/fvfb0/sx222',
#  'train/dr1/fvfb0/sx312',
#  'train/dr1/fvfb0/sx402',
#  'train/dr1/fvfb0/sx42',
#  'train/dr1/fvmh0/sa1',
#  'train/dr1/fvmh0/sa2',
#  'train/dr1/fvmh0/si1466',
#  'train/dr1/fvmh0/si2096',
#  'train/dr1/fvmh0/si836',
#  'train/dr1/fvmh0/sx116',
#  'train/dr1/fvmh0/sx206',
#  'train/dr1/fvmh0/sx26',
#  'train/dr1/fvmh0/sx296',
#  'train/dr1/fvmh0/sx386',
#  'train/dr1/mcpm0/sa1',
#  'train/dr1/mcpm0/sa2',
#  'train/dr1/mcpm0/si1194',
#  'train/dr1/mcpm0/si1824',
#  'train/dr1/mcpm0/si564',
#  'train/dr1/mcpm0/sx114',
#  'train/dr1/mcpm0/sx204',
#  'train/dr1/mcpm0/sx24',
#  'train/dr1/mcpm0/sx294',
#  'train/dr1/mcpm0/sx384',
#  'train/dr1/mdac0/sa1',
#  'train/dr1/mdac0/sa2',
#  'train/dr1/mdac0/si1261',
#  'train/dr1/mdac0/si1837',
#  'train/dr1/mdac0/si631',
#  'train/dr1/mdac0/sx181',
#  'train/dr1/mdac0/sx271',
#  'train/dr1/mdac0/sx361',
#  'train/dr1/mdac0/sx451',
#  'train/dr1/mdac0/sx91',
#  'train/dr1/mdpk0/sa1',
#  'train/dr1/mdpk0/sa2',
#  'train/dr1/mdpk0/si1053',
#  'train/dr1/mdpk0/si1683',
#  'train/dr1/mdpk0/si552',
#  'train/dr1/mdpk0/sx153',
#  'train/dr1/mdpk0/sx243',
#  'train/dr1/mdpk0/sx333',
#  'train/dr1/mdpk0/sx423',
#  'train/dr1/mdpk0/sx63',
#  'train/dr1/medr0/sa1',
#  'train/dr1/medr0/sa2',
#  'train/dr1/medr0/si1374',
#  'train/dr1/medr0/si2004',
#  'train/dr1/medr0/si744',
#  'train/dr1/medr0/sx114',
#  'train/dr1/medr0/sx204',
#  'train/dr1/medr0/sx24',
#  'train/dr1/medr0/sx294',
#  'train/dr1/medr0/sx384',
#  'train/dr1/mgrl0/sa1',
#  'train/dr1/mgrl0/sa2',
#  'train/dr1/mgrl0/si1497',
#  'train/dr1/mgrl0/si2127',
#  'train/dr1/mgrl0/si867',
#  'train/dr1/mgrl0/sx147',
#  'train/dr1/mgrl0/sx237',
#  'train/dr1/mgrl0/sx327',
#  'train/dr1/mgrl0/sx417',
#  'train/dr1/mgrl0/sx57',
#  'train/dr1/mjeb1/sa1',
#  'train/dr1/mjeb1/sa2',
#  'train/dr1/mjeb1/si1467',
#  'train/dr1/mjeb1/si2097',
#  'train/dr1/mjeb1/si837',
#  'train/dr1/mjeb1/sx117',
#  'train/dr1/mjeb1/sx207',
#  'train/dr1/mjeb1/sx27',
#  'train/dr1/mjeb1/sx297',
#  'train/dr1/mjeb1/sx387',
#  'train/dr1/mjwt0/sa1',
#  'train/dr1/mjwt0/sa2',
#  'train/dr1/mjwt0/si1291',
#  'train/dr1/mjwt0/si1381',
#  'train/dr1/mjwt0/si751',
#  'train/dr1/mjwt0/sx121',
#  'train/dr1/mjwt0/sx211',
#  'train/dr1/mjwt0/sx301',
#  'train/dr1/mjwt0/sx31',
#  'train/dr1/mjwt0/sx391',
#  'train/dr1/mkls0/sa1',
#  'train/dr1/mkls0/sa2',
#  'train/dr1/mkls0/si1437',
#  'train/dr1/mkls0/si1533',
#  'train/dr1/mkls0/si2067',
#  'train/dr1/mkls0/sx177',
#  'train/dr1/mkls0/sx267',
#  'train/dr1/mkls0/sx357',
#  'train/dr1/mkls0/sx447',
#  'train/dr1/mkls0/sx87',
#  'train/dr1/mklw0/sa1',
#  'train/dr1/mklw0/sa2',
#  'train/dr1/mklw0/si1571',
#  'train/dr1/mklw0/si1844',
#  'train/dr1/mklw0/si2201',
#  'train/dr1/mklw0/sx131',
#  'train/dr1/mklw0/sx221',
#  'train/dr1/mklw0/sx311',
#  'train/dr1/mklw0/sx401',
#  'train/dr1/mklw0/sx41',
#  'train/dr1/mmgg0/sa1',
#  'train/dr1/mmgg0/sa2',
#  'train/dr1/mmgg0/si1079',
#  'train/dr1/mmgg0/si1709',
#  'train/dr1/mmgg0/si2339',
#  'train/dr1/mmgg0/sx179',
#  'train/dr1/mmgg0/sx269',
#  'train/dr1/mmgg0/sx359',
#  'train/dr1/mmgg0/sx449',
#  'train/dr1/mmgg0/sx89',
#  'train/dr1/mmrp0/sa1',
#  'train/dr1/mmrp0/sa2',
#  'train/dr1/mmrp0/si2034',
#  'train/dr1/mmrp0/si717',
#  'train/dr1/mmrp0/si774',
#  'train/dr1/mmrp0/sx144',
#  'train/dr1/mmrp0/sx234',
#  'train/dr1/mmrp0/sx324',
#  'train/dr1/mmrp0/sx414',
#  'train/dr1/mmrp0/sx54',
#  'train/dr1/mpgh0/sa1',
#  'train/dr1/mpgh0/sa2',
#  'train/dr1/mpgh0/si1554',
#  'train/dr1/mpgh0/si675',
#  'train/dr1/mpgh0/si924',
#  'train/dr1/mpgh0/sx114',
#  'train/dr1/mpgh0/sx204',
#  'train/dr1/mpgh0/sx24',
#  'train/dr1/mpgh0/sx294',
#  'train/dr1/mpgh0/sx384',
#  'train/dr1/mpgr0/sa1',
#  'train/dr1/mpgr0/sa2',
#  'train/dr1/mpgr0/si1410',
#  'train/dr1/mpgr0/si2040',
#  'train/dr1/mpgr0/si780',
#  'train/dr1/mpgr0/sx150',
#  'train/dr1/mpgr0/sx240',
#  'train/dr1/mpgr0/sx330',
#  'train/dr1/mpgr0/sx420',
#  'train/dr1/mpgr0/sx60',
#  'train/dr1/mpsw0/sa1',
#  'train/dr1/mpsw0/sa2',
#  'train/dr1/mpsw0/si1067',
#  'train/dr1/mpsw0/si1697',
#  'train/dr1/mpsw0/si2327',
#  'train/dr1/mpsw0/sx167',
#  'train/dr1/mpsw0/sx24',
#  'train/dr1/mpsw0/sx257',
#  'train/dr1/mpsw0/sx437',
#  'train/dr1/mpsw0/sx77',
#  'train/dr1/mrai0/sa1',
#  'train/dr1/mrai0/sa2',
#  'train/dr1/mrai0/si1954',
#  'train/dr1/mrai0/si2052',
#  'train/dr1/mrai0/si792',
#  'train/dr1/mrai0/sx162',
#  'train/dr1/mrai0/sx252',
#  'train/dr1/mrai0/sx342',
#  'train/dr1/mrai0/sx432',
#  'train/dr1/mrai0/sx72',
#  'train/dr1/mrcg0/sa1',
#  'train/dr1/mrcg0/sa2',
#  'train/dr1/mrcg0/si1428',
#  'train/dr1/mrcg0/si2058',
#  'train/dr1/mrcg0/si798',
#  'train/dr1/mrcg0/sx168',
#  'train/dr1/mrcg0/sx258',
#  'train/dr1/mrcg0/sx348',
#  'train/dr1/mrcg0/sx438',
#  'train/dr1/mrcg0/sx78',
#  'train/dr1/mrdd0/sa1',
#  'train/dr1/mrdd0/sa2',
#  'train/dr1/mrdd0/si1050',
#  'train/dr1/mrdd0/si1680',
#  'train/dr1/mrdd0/si2310',
#  'train/dr1/mrdd0/sx150',
#  'train/dr1/mrdd0/sx240',
#  'train/dr1/mrdd0/sx277',
#  'train/dr1/mrdd0/sx330',
#  'train/dr1/mrdd0/sx60',
#  'train/dr1/mrso0/sa1',
#  'train/dr1/mrso0/sa2',
#  'train/dr1/mrso0/si1206',
#  'train/dr1/mrso0/si1659',
#  'train/dr1/mrso0/si2289',
#  'train/dr1/mrso0/sx129',
#  'train/dr1/mrso0/sx219',
#  'train/dr1/mrso0/sx309',
#  'train/dr1/mrso0/sx39',
#  'train/dr1/mrso0/sx399',
#  'train/dr1/mrws0/sa1',
#  'train/dr1/mrws0/sa2',
#  'train/dr1/mrws0/si1102',
#  'train/dr1/mrws0/si1732',
#  'train/dr1/mrws0/si472',
#  'train/dr1/mrws0/sx112',
#  'train/dr1/mrws0/sx202',
#  'train/dr1/mrws0/sx22',
#  'train/dr1/mrws0/sx292',
#  'train/dr1/mrws0/sx382',
#  'train/dr1/mtjs0/sa1',
#  'train/dr1/mtjs0/sa2',
#  'train/dr1/mtjs0/si1192',
#  'train/dr1/mtjs0/si1822',
#  'train/dr1/mtjs0/si562',
#  'train/dr1/mtjs0/sx112',
#  'train/dr1/mtjs0/sx202',
#  'train/dr1/mtjs0/sx22',
#  'train/dr1/mtjs0/sx292',
#  'train/dr1/mtjs0/sx382',
#  'train/dr1/mtpf0/sa1',
#  'train/dr1/mtpf0/sa2',
#  'train/dr1/mtpf0/si1235',
#  'train/dr1/mtpf0/si1865',
#  'train/dr1/mtpf0/si605',
#  'train/dr1/mtpf0/sx155',
#  'train/dr1/mtpf0/sx245',
#  'train/dr1/mtpf0/sx335',
#  'train/dr1/mtpf0/sx425',
#  'train/dr1/mtpf0/sx65',
#  'train/dr1/mtrr0/sa1',
#  'train/dr1/mtrr0/sa2',
#  'train/dr1/mtrr0/si1548',
#  'train/dr1/mtrr0/si2178',
#  'train/dr1/mtrr0/si918',
#  'train/dr1/mtrr0/sx108',
#  'train/dr1/mtrr0/sx18',
#  'train/dr1/mtrr0/sx198',
#  'train/dr1/mtrr0/sx288',
#  'train/dr1/mtrr0/sx378',
#  'train/dr1/mwad0/sa1',
#  'train/dr1/mwad0/sa2',
#  'train/dr1/mwad0/si1062',
#  'train/dr1/mwad0/si1749',
#  'train/dr1/mwad0/si2322',
#  'train/dr1/mwad0/sx162',
#  'train/dr1/mwad0/sx252',
#  'train/dr1/mwad0/sx342',
#  'train/dr1/mwad0/sx432',
#  'train/dr1/mwad0/sx72',
#  'train/dr1/mwar0/sa1',
#  'train/dr1/mwar0/sa2',
#  'train/dr1/mwar0/si1045',
#  'train/dr1/mwar0/si1675',
#  'train/dr1/mwar0/si2305',
#  'train/dr1/mwar0/sx145',
#  'train/dr1/mwar0/sx235',
#  'train/dr1/mwar0/sx325',
#  'train/dr1/mwar0/sx415',
#  'train/dr1/mwar0/sx55',
#  'train/dr2/faem0/sa1',
#  'train/dr2/faem0/sa2',
#  'train/dr2/faem0/si1392',
#  'train/dr2/faem0/si2022',
#  'train/dr2/faem0/si762',
#  'train/dr2/faem0/sx132',
#  'train/dr2/faem0/sx222',
#  'train/dr2/faem0/sx312',
#  'train/dr2/faem0/sx402',
#  'train/dr2/faem0/sx42',
#  'train/dr2/fajw0/sa1',
#  'train/dr2/fajw0/sa2',
#  'train/dr2/fajw0/si1263',
#  'train/dr2/fajw0/si1893',
#  'train/dr2/fajw0/si633',
#  'train/dr2/fajw0/sx183',
#  'train/dr2/fajw0/sx273',
#  'train/dr2/fajw0/sx3',
#  'train/dr2/fajw0/sx363',
#  'train/dr2/fajw0/sx93',
#  'train/dr2/fcaj0/sa1',
#  'train/dr2/fcaj0/sa2',
#  'train/dr2/fcaj0/si1479',
#  'train/dr2/fcaj0/si1804',
#  'train/dr2/fcaj0/si849',
#  'train/dr2/fcaj0/sx129',
#  'train/dr2/fcaj0/sx219',
#  'train/dr2/fcaj0/sx309',
#  'train/dr2/fcaj0/sx39',
#  'train/dr2/fcaj0/sx399',
#  'train/dr2/fcmm0/sa1',
#  'train/dr2/fcmm0/sa2',
#  'train/dr2/fcmm0/si1083',
#  'train/dr2/fcmm0/si1957',
#  'train/dr2/fcmm0/si453',
#  'train/dr2/fcmm0/sx183',
#  'train/dr2/fcmm0/sx273',
#  'train/dr2/fcmm0/sx363',
#  'train/dr2/fcmm0/sx420',
#  'train/dr2/fcmm0/sx93',
#  'train/dr2/fcyl0/sa1',
#  'train/dr2/fcyl0/sa2',
#  'train/dr2/fcyl0/si1297',
#  'train/dr2/fcyl0/si1927',
#  'train/dr2/fcyl0/si667',
#  'train/dr2/fcyl0/sx127',
#  'train/dr2/fcyl0/sx217',
#  'train/dr2/fcyl0/sx349',
#  'train/dr2/fcyl0/sx37',
#  'train/dr2/fcyl0/sx397',
#  'train/dr2/fdas1/sa1',
#  'train/dr2/fdas1/sa2',
#  'train/dr2/fdas1/si1461',
#  'train/dr2/fdas1/si2091',
#  'train/dr2/fdas1/si831',
#  'train/dr2/fdas1/sx111',
#  'train/dr2/fdas1/sx201',
#  'train/dr2/fdas1/sx21',
#  'train/dr2/fdas1/sx291',
#  'train/dr2/fdas1/sx381',
#  'train/dr2/fdnc0/sa1',
#  'train/dr2/fdnc0/sa2',
#  'train/dr2/fdnc0/si1278',
#  'train/dr2/fdnc0/si1908',
#  'train/dr2/fdnc0/si2287',
#  'train/dr2/fdnc0/sx108',
#  'train/dr2/fdnc0/sx18',
#  'train/dr2/fdnc0/sx198',
#  'train/dr2/fdnc0/sx288',
#  'train/dr2/fdnc0/sx378',
#  'train/dr2/fdxw0/sa1',
#  'train/dr2/fdxw0/sa2',
#  'train/dr2/fdxw0/si1511',
#  'train/dr2/fdxw0/si2141',
#  'train/dr2/fdxw0/si881',
#  'train/dr2/fdxw0/sx161',
#  'train/dr2/fdxw0/sx251',
#  'train/dr2/fdxw0/sx341',
#  'train/dr2/fdxw0/sx431',
#  'train/dr2/fdxw0/sx71',
#  'train/dr2/feac0/sa1',
#  'train/dr2/feac0/sa2',
#  'train/dr2/feac0/si1245',
#  'train/dr2/feac0/si1875',
#  'train/dr2/feac0/si615',
#  'train/dr2/feac0/sx165',
#  'train/dr2/feac0/sx255',
#  'train/dr2/feac0/sx345',
#  'train/dr2/feac0/sx435',
#  'train/dr2/feac0/sx75',
#  'train/dr2/fhlm0/sa1',
#  'train/dr2/fhlm0/sa2',
#  'train/dr2/fhlm0/si1560',
#  'train/dr2/fhlm0/si2190',
#  'train/dr2/fhlm0/si930',
#  'train/dr2/fhlm0/sx120',
#  'train/dr2/fhlm0/sx210',
#  'train/dr2/fhlm0/sx300',
#  'train/dr2/fhlm0/sx349',
#  'train/dr2/fhlm0/sx390',
#  'train/dr2/fjkl0/sa1',
#  'train/dr2/fjkl0/sa2',
#  'train/dr2/fjkl0/si1562',
#  'train/dr2/fjkl0/si2192',
#  'train/dr2/fjkl0/si932',
#  'train/dr2/fjkl0/sx122',
#  'train/dr2/fjkl0/sx212',
#  'train/dr2/fjkl0/sx302',
#  'train/dr2/fjkl0/sx32',
#  'train/dr2/fjkl0/sx392',
#  'train/dr2/fkaa0/sa1',
#  'train/dr2/fkaa0/sa2',
#  'train/dr2/fkaa0/si1208',
#  'train/dr2/fkaa0/si1838',
#  'train/dr2/fkaa0/si578',
#  'train/dr2/fkaa0/sx128',
#  'train/dr2/fkaa0/sx218',
#  'train/dr2/fkaa0/sx308',
#  'train/dr2/fkaa0/sx38',
#  'train/dr2/fkaa0/sx398',
#  'train/dr2/flma0/sa1',
#  'train/dr2/flma0/sa2',
#  'train/dr2/flma0/si1243',
#  'train/dr2/flma0/si1873',
#  'train/dr2/flma0/si613',
#  'train/dr2/flma0/sx163',
#  'train/dr2/flma0/sx253',
#  'train/dr2/flma0/sx343',
#  'train/dr2/flma0/sx433',
#  'train/dr2/flma0/sx73',
#  'train/dr2/flmc0/sa1',
#  'train/dr2/flmc0/sa2',
#  'train/dr2/flmc0/si1372',
#  'train/dr2/flmc0/si2002',
#  'train/dr2/flmc0/si742',
#  'train/dr2/flmc0/sx112',
#  'train/dr2/flmc0/sx22',
#  'train/dr2/flmc0/sx292',
#  'train/dr2/flmc0/sx336',
#  'train/dr2/flmc0/sx382',
#  'train/dr2/fmjb0/sa1',
#  'train/dr2/fmjb0/sa2',
#  'train/dr2/fmjb0/si1177',
#  'train/dr2/fmjb0/si1807',
#  'train/dr2/fmjb0/si547',
#  'train/dr2/fmjb0/sx187',
#  'train/dr2/fmjb0/sx277',
#  'train/dr2/fmjb0/sx367',
#  'train/dr2/fmjb0/sx7',
#  'train/dr2/fmjb0/sx97',
#  'train/dr2/fmkf0/sa1',
#  'train/dr2/fmkf0/sa2',
#  'train/dr2/fmkf0/si1018',
#  'train/dr2/fmkf0/si1536',
#  'train/dr2/fmkf0/si906',
#  'train/dr2/fmkf0/sx186',
#  'train/dr2/fmkf0/sx276',
#  'train/dr2/fmkf0/sx366',
#  'train/dr2/fmkf0/sx6',
#  'train/dr2/fmkf0/sx96',
#  'train/dr2/fmmh0/sa1',
#  'train/dr2/fmmh0/sa2',
#  'train/dr2/fmmh0/si1537',
#  'train/dr2/fmmh0/si2167',
#  'train/dr2/fmmh0/si907',
#  'train/dr2/fmmh0/sx187',
#  'train/dr2/fmmh0/sx367',
#  'train/dr2/fmmh0/sx420',
#  'train/dr2/fmmh0/sx7',
#  'train/dr2/fmmh0/sx97',
#  'train/dr2/fpjf0/sa1',
#  'train/dr2/fpjf0/sa2',
#  'train/dr2/fpjf0/si1046',
#  'train/dr2/fpjf0/si1259',
#  'train/dr2/fpjf0/si1676',
#  'train/dr2/fpjf0/sx146',
#  'train/dr2/fpjf0/sx236',
#  'train/dr2/fpjf0/sx326',
#  'train/dr2/fpjf0/sx352',
#  'train/dr2/fpjf0/sx56',
#  'train/dr2/frll0/sa1',
#  'train/dr2/frll0/sa2',
#  'train/dr2/frll0/si1514',
#  'train/dr2/frll0/si805',
#  'train/dr2/frll0/si884',
#  'train/dr2/frll0/sx164',
#  'train/dr2/frll0/sx254',
#  'train/dr2/frll0/sx344',
#  'train/dr2/frll0/sx434',
#  'train/dr2/frll0/sx74',
#  'train/dr2/fscn0/sa1',
#  'train/dr2/fscn0/sa2',
#  'train/dr2/fscn0/si1886',
#  'train/dr2/fscn0/si626',
#  'train/dr2/fscn0/si705',
#  'train/dr2/fscn0/sx176',
#  'train/dr2/fscn0/sx266',
#  'train/dr2/fscn0/sx356',
#  'train/dr2/fscn0/sx446',
#  'train/dr2/fscn0/sx86',
#  'train/dr2/fskl0/sa1',
#  'train/dr2/fskl0/sa2',
#  'train/dr2/fskl0/si1529',
#  'train/dr2/fskl0/si2159',
#  'train/dr2/fskl0/si899',
#  'train/dr2/fskl0/sx179',
#  'train/dr2/fskl0/sx269',
#  'train/dr2/fskl0/sx359',
#  'train/dr2/fskl0/sx449',
#  'train/dr2/fskl0/sx89',
#  'train/dr2/fsrh0/sa1',
#  'train/dr2/fsrh0/sa2',
#  'train/dr2/fsrh0/si1719',
#  'train/dr2/fsrh0/si1931',
#  'train/dr2/fsrh0/si671',
#  'train/dr2/fsrh0/sx131',
#  'train/dr2/fsrh0/sx221',
#  'train/dr2/fsrh0/sx311',
#  'train/dr2/fsrh0/sx401',
#  'train/dr2/fsrh0/sx41',
#  'train/dr2/ftmg0/sa1',
#  'train/dr2/ftmg0/sa2',
#  'train/dr2/ftmg0/si1532',
#  'train/dr2/ftmg0/si2162',
#  'train/dr2/ftmg0/si902',
#  'train/dr2/ftmg0/sx182',
#  'train/dr2/ftmg0/sx272',
#  'train/dr2/ftmg0/sx362',
#  'train/dr2/ftmg0/sx452',
#  'train/dr2/ftmg0/sx92',
#  'train/dr2/marc0/sa1',
#  'train/dr2/marc0/sa2',
#  'train/dr2/marc0/si1188',
#  'train/dr2/marc0/si1818',
#  'train/dr2/marc0/si558',
#  'train/dr2/marc0/sx108',
#  'train/dr2/marc0/sx18',
#  'train/dr2/marc0/sx198',
#  'train/dr2/marc0/sx288',
#  'train/dr2/marc0/sx378',
#  'train/dr2/mbjv0/sa1',
#  'train/dr2/mbjv0/sa2',
#  'train/dr2/mbjv0/si1247',
#  'train/dr2/mbjv0/si1877',
#  'train/dr2/mbjv0/si617',
#  'train/dr2/mbjv0/sx167',
#  'train/dr2/mbjv0/sx257',
#  'train/dr2/mbjv0/sx347',
#  'train/dr2/mbjv0/sx437',
#  'train/dr2/mbjv0/sx77',
#  'train/dr2/mcew0/sa1',
#  'train/dr2/mcew0/sa2',
#  'train/dr2/mcew0/si1442',
#  'train/dr2/mcew0/si2072',
#  'train/dr2/mcew0/si812',
#  'train/dr2/mcew0/sx182',
#  'train/dr2/mcew0/sx272',
#  'train/dr2/mcew0/sx362',
#  'train/dr2/mcew0/sx452',
#  'train/dr2/mcew0/sx92',
#  'train/dr2/mctm0/sa1',
#  'train/dr2/mctm0/sa2',
#  'train/dr2/mctm0/si1350',
#  'train/dr2/mctm0/si1980',
#  'train/dr2/mctm0/si720',
#  'train/dr2/mctm0/sx180',
#  'train/dr2/mctm0/sx270',
#  'train/dr2/mctm0/sx360',
#  'train/dr2/mctm0/sx450',
#  'train/dr2/mctm0/sx90',
#  'train/dr2/mdbp0/sa1',
#  'train/dr2/mdbp0/sa2',
#  'train/dr2/mdbp0/si1158',
#  'train/dr2/mdbp0/si1788',
#  'train/dr2/mdbp0/si528',
#  'train/dr2/mdbp0/sx168',
#  'train/dr2/mdbp0/sx258',
#  'train/dr2/mdbp0/sx348',
#  'train/dr2/mdbp0/sx438',
#  'train/dr2/mdbp0/sx78',
#  'train/dr2/mdem0/sa1',
#  'train/dr2/mdem0/sa2',
#  'train/dr2/mdem0/si1868',
#  'train/dr2/mdem0/si608',
#  'train/dr2/mdem0/si800',
#  'train/dr2/mdem0/sx158',
#  'train/dr2/mdem0/sx248',
#  'train/dr2/mdem0/sx338',
#  'train/dr2/mdem0/sx428',
#  'train/dr2/mdem0/sx68',
#  'train/dr2/mdlb0/sa1',
#  'train/dr2/mdlb0/sa2',
#  'train/dr2/mdlb0/si1306',
#  'train/dr2/mdlb0/si1936',
#  'train/dr2/mdlb0/si676',
#  'train/dr2/mdlb0/sx136',
#  'train/dr2/mdlb0/sx226',
#  'train/dr2/mdlb0/sx316',
#  'train/dr2/mdlb0/sx406',
#  'train/dr2/mdlb0/sx46',
#  'train/dr2/mdlc2/sa1',
#  'train/dr2/mdlc2/sa2',
#  'train/dr2/mdlc2/si1614',
#  'train/dr2/mdlc2/si2244',
#  'train/dr2/mdlc2/si984',
#  'train/dr2/mdlc2/sx174',
#  'train/dr2/mdlc2/sx264',
#  'train/dr2/mdlc2/sx354',
#  'train/dr2/mdlc2/sx444',
#  'train/dr2/mdlc2/sx84',
#  'train/dr2/mdmt0/sa1',
#  'train/dr2/mdmt0/sa2',
#  'train/dr2/mdmt0/si1832',
#  'train/dr2/mdmt0/si2341',
#  'train/dr2/mdmt0/si572',
#  'train/dr2/mdmt0/sx122',
#  'train/dr2/mdmt0/sx212',
#  'train/dr2/mdmt0/sx302',
#  'train/dr2/mdmt0/sx32',
#  'train/dr2/mdmt0/sx392',
#  'train/dr2/mdps0/sa1',
#  'train/dr2/mdps0/sa2',
#  'train/dr2/mdps0/si1651',
#  'train/dr2/mdps0/si1979',
#  'train/dr2/mdps0/si719',
#  'train/dr2/mdps0/sx179',
#  'train/dr2/mdps0/sx269',
#  'train/dr2/mdps0/sx359',
#  'train/dr2/mdps0/sx449',
#  'train/dr2/mdps0/sx89',
#  'train/dr2/mdss0/sa1',
#  'train/dr2/mdss0/sa2',
#  'train/dr2/mdss0/si1881',
#  'train/dr2/mdss0/si2087',
#  'train/dr2/mdss0/si621',
#  'train/dr2/mdss0/sx171',
#  'train/dr2/mdss0/sx261',
#  'train/dr2/mdss0/sx351',
#  'train/dr2/mdss0/sx441',
#  'train/dr2/mdss0/sx81',
#  'train/dr2/mdwd0/sa1',
#  'train/dr2/mdwd0/sa2',
#  'train/dr2/mdwd0/si1260',
#  'train/dr2/mdwd0/si1890',
#  'train/dr2/mdwd0/si557',
#  'train/dr2/mdwd0/sx180',
#  'train/dr2/mdwd0/sx270',
#  'train/dr2/mdwd0/sx360',
#  'train/dr2/mdwd0/sx450',
#  'train/dr2/mdwd0/sx90',
#  'train/dr2/mefg0/sa1',
#  'train/dr2/mefg0/sa2',
#  'train/dr2/mefg0/si465',
#  'train/dr2/mefg0/si491',
#  'train/dr2/mefg0/si598',
#  'train/dr2/mefg0/sx105',
#  'train/dr2/mefg0/sx15',
#  'train/dr2/mefg0/sx195',
#  'train/dr2/mefg0/sx285',
#  'train/dr2/mefg0/sx375',
#  'train/dr2/mhrm0/sa1',
#  'train/dr2/mhrm0/sa2',
#  'train/dr2/mhrm0/si1475',
#  'train/dr2/mhrm0/si2218',
#  'train/dr2/mhrm0/si958',
#  'train/dr2/mhrm0/sx148',
#  'train/dr2/mhrm0/sx238',
#  'train/dr2/mhrm0/sx328',
#  'train/dr2/mhrm0/sx418',
#  'train/dr2/mhrm0/sx58',
#  'train/dr2/mjae0/sa1',
#  'train/dr2/mjae0/sa2',
#  'train/dr2/mjae0/si1524',
#  'train/dr2/mjae0/si1999',
#  'train/dr2/mjae0/si2154',
#  'train/dr2/mjae0/sx174',
#  'train/dr2/mjae0/sx264',
#  'train/dr2/mjae0/sx354',
#  'train/dr2/mjae0/sx444',
#  'train/dr2/mjae0/sx84',
#  'train/dr2/mjbg0/sa1',
#  'train/dr2/mjbg0/sa2',
#  'train/dr2/mjbg0/si1232',
#  'train/dr2/mjbg0/si1724',
#  'train/dr2/mjbg0/si1862',
#  'train/dr2/mjbg0/sx152',
#  'train/dr2/mjbg0/sx242',
#  'train/dr2/mjbg0/sx332',
#  'train/dr2/mjbg0/sx422',
#  'train/dr2/mjbg0/sx62',
#  'train/dr2/mjde0/sa1',
#  'train/dr2/mjde0/sa2',
#  'train/dr2/mjde0/si1120',
#  'train/dr2/mjde0/si463',
#  'train/dr2/mjde0/si490',
#  'train/dr2/mjde0/sx130',
#  'train/dr2/mjde0/sx220',
#  'train/dr2/mjde0/sx310',
#  'train/dr2/mjde0/sx40',
#  'train/dr2/mjde0/sx400',
#  'train/dr2/mjeb0/sa1',
#  'train/dr2/mjeb0/sa2',
#  'train/dr2/mjeb0/si1286',
#  'train/dr2/mjeb0/si1916',
#  'train/dr2/mjeb0/si656',
#  'train/dr2/mjeb0/sx170',
#  'train/dr2/mjeb0/sx206',
#  'train/dr2/mjeb0/sx26',
#  'train/dr2/mjeb0/sx296',
#  'train/dr2/mjeb0/sx386',
#  'train/dr2/mjhi0/sa1',
#  'train/dr2/mjhi0/sa2',
#  'train/dr2/mjhi0/si1328',
#  'train/dr2/mjhi0/si555',
#  'train/dr2/mjhi0/si698',
#  'train/dr2/mjhi0/sx158',
#  'train/dr2/mjhi0/sx248',
#  'train/dr2/mjhi0/sx338',
#  'train/dr2/mjhi0/sx428',
#  'train/dr2/mjhi0/sx68',
#  'train/dr2/mjma0/sa1',
#  'train/dr2/mjma0/sa2',
#  'train/dr2/mjma0/si1495',
#  'train/dr2/mjma0/si2125',
#  'train/dr2/mjma0/si865',
#  'train/dr2/mjma0/sx145',
#  'train/dr2/mjma0/sx235',
#  'train/dr2/mjma0/sx325',
#  'train/dr2/mjma0/sx415',
#  'train/dr2/mjma0/sx55',
#  'train/dr2/mjmd0/sa1',
#  'train/dr2/mjmd0/sa2',
#  'train/dr2/mjmd0/si1028',
#  'train/dr2/mjmd0/si1658',
#  'train/dr2/mjmd0/si2288',
#  'train/dr2/mjmd0/sx128',
#  'train/dr2/mjmd0/sx218',
#  'train/dr2/mjmd0/sx308',
#  'train/dr2/mjmd0/sx38',
#  'train/dr2/mjmd0/sx398',
#  'train/dr2/mjpm0/sa1',
#  'train/dr2/mjpm0/sa2',
#  'train/dr2/mjpm0/si1368',
#  'train/dr2/mjpm0/si1998',
#  'train/dr2/mjpm0/si738',
#  'train/dr2/mjpm0/sx108',
#  'train/dr2/mjpm0/sx18',
#  'train/dr2/mjpm0/sx198',
#  'train/dr2/mjpm0/sx288',
#  'train/dr2/mjpm0/sx378',
#  'train/dr2/mjrp0/sa1',
#  'train/dr2/mjrp0/sa2',
#  'train/dr2/mjrp0/si1835',
#  'train/dr2/mjrp0/si1845',
#  'train/dr2/mjrp0/si585',
#  'train/dr2/mjrp0/sx135',
#  'train/dr2/mjrp0/sx225',
#  'train/dr2/mjrp0/sx315',
#  'train/dr2/mjrp0/sx405',
#  'train/dr2/mjrp0/sx45',
#  'train/dr2/mkah0/sa1',
#  'train/dr2/mkah0/sa2',
#  'train/dr2/mkah0/si1528',
#  'train/dr2/mkah0/si2158',
#  'train/dr2/mkah0/si898',
#  'train/dr2/mkah0/sx178',
#  'train/dr2/mkah0/sx268',
#  'train/dr2/mkah0/sx358',
#  'train/dr2/mkah0/sx448',
#  'train/dr2/mkah0/sx88',
#  'train/dr2/mkaj0/sa1',
#  'train/dr2/mkaj0/sa2',
#  'train/dr2/mkaj0/si1414',
#  'train/dr2/mkaj0/si2044',
#  'train/dr2/mkaj0/si784',
#  'train/dr2/mkaj0/sx154',
#  'train/dr2/mkaj0/sx244',
#  'train/dr2/mkaj0/sx334',
#  'train/dr2/mkaj0/sx424',
#  'train/dr2/mkaj0/sx64',
#  'train/dr2/mkdt0/sa1',
#  'train/dr2/mkdt0/sa2',
#  'train/dr2/mkdt0/si2153',
#  'train/dr2/mkdt0/si814',
#  'train/dr2/mkdt0/si893',
#  'train/dr2/mkdt0/sx173',
#  'train/dr2/mkdt0/sx263',
#  'train/dr2/mkdt0/sx353',
#  'train/dr2/mkdt0/sx443',
#  'train/dr2/mkdt0/sx83',
#  'train/dr2/mkjo0/sa1',
#  'train/dr2/mkjo0/sa2',
#  'train/dr2/mkjo0/si1517',
#  'train/dr2/mkjo0/si2147',
#  'train/dr2/mkjo0/si887',
#  'train/dr2/mkjo0/sx167',
#  'train/dr2/mkjo0/sx257',
#  'train/dr2/mkjo0/sx424',
#  'train/dr2/mkjo0/sx437',
#  'train/dr2/mkjo0/sx77',
#  'train/dr2/mmaa0/sa1',
#  'train/dr2/mmaa0/sa2',
#  'train/dr2/mmaa0/si1588',
#  'train/dr2/mmaa0/si2105',
#  'train/dr2/mmaa0/si845',
#  'train/dr2/mmaa0/sx125',
#  'train/dr2/mmaa0/sx215',
#  'train/dr2/mmaa0/sx305',
#  'train/dr2/mmaa0/sx35',
#  'train/dr2/mmaa0/sx395',
#  'train/dr2/mmag0/sa1',
#  'train/dr2/mmag0/sa2',
#  'train/dr2/mmag0/si1126',
#  'train/dr2/mmag0/si1756',
#  'train/dr2/mmag0/si496',
#  'train/dr2/mmag0/sx136',
#  'train/dr2/mmag0/sx226',
#  'train/dr2/mmag0/sx316',
#  'train/dr2/mmag0/sx406',
#  'train/dr2/mmag0/sx46',
#  'train/dr2/mmds0/sa1',
#  'train/dr2/mmds0/sa2',
#  'train/dr2/mmds0/si1343',
#  'train/dr2/mmds0/si1973',
#  'train/dr2/mmds0/si713',
#  'train/dr2/mmds0/sx173',
#  'train/dr2/mmds0/sx263',
#  'train/dr2/mmds0/sx353',
#  'train/dr2/mmds0/sx443',
#  'train/dr2/mmds0/sx83',
#  'train/dr2/mmgk0/sa1',
#  'train/dr2/mmgk0/sa2',
#  'train/dr2/mmgk0/si1322',
#  'train/dr2/mmgk0/si1952',
#  'train/dr2/mmgk0/si692',
#  'train/dr2/mmgk0/sx152',
#  'train/dr2/mmgk0/sx242',
#  'train/dr2/mmgk0/sx332',
#  'train/dr2/mmgk0/sx422',
#  'train/dr2/mmgk0/sx62',
#  'train/dr2/mmxs0/sa1',
#  'train/dr2/mmxs0/sa2',
#  'train/dr2/mmxs0/si2136',
#  'train/dr2/mmxs0/si629',
#  'train/dr2/mmxs0/si876',
#  'train/dr2/mmxs0/sx156',
#  'train/dr2/mmxs0/sx246',
#  'train/dr2/mmxs0/sx336',
#  'train/dr2/mmxs0/sx426',
#  'train/dr2/mmxs0/sx66',
#  'train/dr2/mppc0/sa1',
#  'train/dr2/mppc0/sa2',
#  'train/dr2/mppc0/si1412',
#  'train/dr2/mppc0/si2042',
#  'train/dr2/mppc0/si782',
#  'train/dr2/mppc0/sx152',
#  'train/dr2/mppc0/sx242',
#  'train/dr2/mppc0/sx332',
#  'train/dr2/mppc0/sx422',
#  'train/dr2/mppc0/sx62',
#  'train/dr2/mprb0/sa1',
#  'train/dr2/mprb0/sa2',
#  'train/dr2/mprb0/si1205',
#  'train/dr2/mprb0/si1215',
#  'train/dr2/mprb0/si575',
#  'train/dr2/mprb0/sx125',
#  'train/dr2/mprb0/sx215',
#  'train/dr2/mprb0/sx305',
#  'train/dr2/mprb0/sx35',
#  'train/dr2/mprb0/sx395',
#  'train/dr2/mrab0/sa1',
#  'train/dr2/mrab0/sa2',
#  'train/dr2/mrab0/si1224',
#  'train/dr2/mrab0/si1854',
#  'train/dr2/mrab0/si594',
#  'train/dr2/mrab0/sx144',
#  'train/dr2/mrab0/sx234',
#  'train/dr2/mrab0/sx324',
#  'train/dr2/mrab0/sx414',
#  'train/dr2/mrab0/sx54',
#  'train/dr2/mrcw0/sa1',
#  'train/dr2/mrcw0/sa2',
#  'train/dr2/mrcw0/si1371',
#  'train/dr2/mrcw0/si2001',
#  'train/dr2/mrcw0/si741',
#  'train/dr2/mrcw0/sx111',
#  'train/dr2/mrcw0/sx201',
#  'train/dr2/mrcw0/sx21',
#  'train/dr2/mrcw0/sx291',
#  'train/dr2/mrcw0/sx381',
#  'train/dr2/mrfk0/sa1',
#  'train/dr2/mrfk0/sa2',
#  'train/dr2/mrfk0/si1076',
#  'train/dr2/mrfk0/si1706',
#  'train/dr2/mrfk0/si2336',
#  'train/dr2/mrfk0/sx176',
#  'train/dr2/mrfk0/sx266',
#  'train/dr2/mrfk0/sx356',
#  'train/dr2/mrfk0/sx446',
#  'train/dr2/mrfk0/sx86',
#  'train/dr2/mrgs0/sa1',
#  'train/dr2/mrgs0/sa2',
#  'train/dr2/mrgs0/si1356',
#  'train/dr2/mrgs0/si1986',
#  'train/dr2/mrgs0/si726',
#  'train/dr2/mrgs0/sx186',
#  'train/dr2/mrgs0/sx276',
#  'train/dr2/mrgs0/sx366',
#  'train/dr2/mrgs0/sx6',
#  'train/dr2/mrgs0/sx96',
#  'train/dr2/mrhl0/sa1',
#  'train/dr2/mrhl0/sa2',
#  'train/dr2/mrhl0/si1515',
#  'train/dr2/mrhl0/si2145',
#  'train/dr2/mrhl0/si885',
#  'train/dr2/mrhl0/sx165',
#  'train/dr2/mrhl0/sx255',
#  'train/dr2/mrhl0/sx345',
#  'train/dr2/mrhl0/sx435',
#  'train/dr2/mrhl0/sx75',
#  ...]

# %% [markdown]
# ### Example 3: read_dataframe() to read column oriented files
#
# - Reads local or remote files into a DataFrame
# - is a wrapper around pd.read_csv() with useful presets and options
#     + assumes no header
#     + tab delimited by default, but can handle any sep
#     + strip=True strips white space at edges from a string datafield
#     + does a reasonable automatic data type casting
#     + ...

# %%
fname = 'mini_corpus.txt'
dir = '../pyspch/data/'
dir ='HTTPS://homes.esat.kuleuven.be/~spchlab/data/misc/'
corpus = Spch.read_dataframe(dir+fname,names=['file','t0','t1','text'],strip=True)
corpus.dtypes, corpus
# Out:
# (file     object
#  t0      float64
#  t1      float64
#  text     object
#  dtype: object,
#         file   t0   t1                text
#  0  friendly  0.0 -1.0  friendly computers
#  1      beed  0.0 -1.0      beed bad booed
#  2        f1  0.1  1.3        misinterpret
#  3        f1  1.3  2.7        expansionist
#  4        f1  2.8  3.7         circumspect)

# %%
# read a segmentation datafile
dir='https://homes.esat.kuleuven.be/~spchlab/data/'
file = "timit/audio/train/si1027"
# get segmentations
segwrd = Spch.read_dataframe(dir+file+ ".wrd",names=['t0','t1','seg'],sep='\s+')
print(segwrd.dtypes)
segwrd
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-c3bad55c212d> in <module>
#       3 file = "timit/si1027"
#       4 # get segmentations
# ----> 5 segwrd = Spch.read_dataframe(dir+file+ ".wrd",names=['t0','t1','seg'],sep='\s+')
#       6 print(segwrd.dtypes)
#       7 segwrd
#
# c:\users\compi\nextcloud\github\pyspch\pyspch\core\file_tools.py in read_dataframe(resource, sep, names, dtype, strip)
#      46         strip   Boolean, strip white space at edges of a datafield (Default is True)
#      47     '''
# ---> 48     df = pd.read_csv(resource,sep=sep,header=None,names=names,dtype=dtype)
#      49     # this will convert object dtypes to string (most of the time)
#      50     df = df.convert_dtypes()
#
# ~\Anaconda3\envs\py37\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~\Anaconda3\envs\py37\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     435     # See https://github.com/python/mypy/issues/1297
#     436     fp_or_buf, _, compression, should_close = get_filepath_or_buffer(
# --> 437         filepath_or_buffer, encoding, compression
#     438     )
#     439     kwds["compression"] = compression
#
# ~\Anaconda3\envs\py37\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     181     if isinstance(filepath_or_buffer, str) and is_url(filepath_or_buffer):
#     182         # TODO: fsspec can also handle HTTP via requests, but leaving this unchanged
# --> 183         req = urlopen(filepath_or_buffer)
#     184         content_encoding = req.headers.get("Content-Encoding", None)
#     185         if content_encoding == "gzip":
#
# ~\Anaconda3\envs\py37\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     135     import urllib.request
#     136
# --> 137     return urllib.request.urlopen(*args, **kwargs)
#     138
#     139
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ### Reading TIMIT transcriptions files

# %%
fn1 = 'timit/sa1.txt'
#fn1="timit/phones-61-48-39-41.txt"
fname='https://homes.esat.kuleuven.be/~spchlab/data/'
transcript = Spch.read_data_file(fname+fn1)[0].strip().split(None,2)
print('Samples: ',int(transcript[0]),int(transcript[1]))
print('Transcript: ',transcript[2].strip('.,!?:;'))
# Out:
# Samples:  0 46797
# Transcript:  She had your dark suit in greasy wash water all year

# %% [markdown]
# ### Reading Mapping files and converting to dictionary

# %%
fn1="timit/phones-61-48-39-41.txt"
fname='https://homes.esat.kuleuven.be/~spchlab/data/'
transcript = Spch.read_data_file(fname+fn1)
cols = Spch.read_data_file(fname+fn1, maxcols = 4)
dict(zip(cols[0],cols[3]))
# Out:
# {'aa': 'ao'}

# %% [markdown]
# ## (TIMIT) Segmentation Files
#
# Segmentation Files are assumed to be in the format
#
# t0  t1   seg
# ....
#
#
# #### time units
# t0, t1 are begin and end-times of segment 'seg'
# the units of time, can be specified in the read_seg_file() module with 'dt', by default segmentation times are given in seconds;
# in timit it is often in samples (with SR=16000), thus use dt=1/16000
#
# #### phonetic symbols
# Phonetic transcriptions come in a variety of phonetic symbol sets.
# These utilities include default definitions (and orderings) of **TIMIT48** and **TIMIT41**.   TIMIT48 is the default used in experiments with TIMIT.   TIMIT41 is our own more compact version inspired by the alphabet in the CMU dictionaries, with 1 additional closure ('cl') symbol.
#
# A number of mappings between the different alphabets are foreseen.  To apply them use the field 'xlat' at time of reading and specify the desired translation:  timit61_48, timit61_41, ..
# These are simple dictionary based mappings.

# %%
# read a datafile
dir='https://homes.esat.kuleuven.be/~spchlab/data/'
file = "timit/si1027" #@param {type:"string"}
wavfile = dir+file+".wav" 
wavdata, sr = Spch.audio.load(wavfile)
spg1 = Sps.spectrogram(wavdata,sample_rate=sr,n_mels=None)

# get segmentations
segwrd = Spch.timit.read_seg_file(dir+file+ ".wrd",dt=1/sr,fmt='float32')
segphn61 = Spch.timit.read_seg_file(dir+file+ ".phn",dt=1/sr,fmt='float32')
segphn = Spch.timit.read_seg_file(dir+file+ ".phn",dt=1/sr,fmt='float32',xlat='timit61_41')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-9-61610304adcd> in <module>
#       3 file = "timit/si1027" #@param {type:"string"}
#       4 wavfile = dir+file+".wav"
# ----> 5 wavdata, sr = Spch.audio.load(wavfile)
#       6 spg1 = Sps.spectrogram(wavdata,sample_rate=sr,n_mels=None)
#       7
#
# c:\users\compi\nextcloud\github\pyspch\pyspch\core\audio.py in load(resource, sample_rate, **kwargs)
#      93     '''
#      94
# ---> 95     fobj = read_fobj(resource)
#      96     data, sample_rate = librosa.load(fobj,dtype='float32',sr=sample_rate,**kwargs)
#      97     # sample rate conversion may result in values exceeding +-1, so a little bit of clipping
#
# c:\users\compi\nextcloud\github\pyspch\pyspch\core\file_tools.py in read_fobj(resource)
#      32     and reads all data into a BytesIO object
#      33     '''
# ---> 34     return(io.BytesIO(open_fobj(resource).read()))
#      35
#      36
#
# c:\users\compi\nextcloud\github\pyspch\pyspch\core\file_tools.py in open_fobj(resource)
#      21     parsed=urlparse(resource)
#      22     if(parsed.scheme == 'https'):
# ---> 23         f = urlopen(resource)
#      24     else:
#      25         f = open(resource,"rb")
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\envs\py37\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
fig = Spd.PlotSpg(spg1,wavdata=wavdata,segwav=segwrd,segspg=segphn,sample_rate=sr)
display(fig)
display(Audio(data=wavdata,rate=sr))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2cc2dac54d53> in <module>
# ----> 1 fig = Spd.PlotSpg(spg1,wavdata=wavdata,segwav=segwrd,segspg=segphn,sample_rate=sr)
#       2 display(fig)
#       3 display(Audio(data=wavdata,rate=sr))
#
# NameError: name 'spg1' is not defined
